# %% [markdown]
# # 1. Ý tưởng

# %% [markdown]
# - Công đoạn đầu tiên của **Data Analysis** là **thu thập data**, để mở đầu ta, nói về chủ đề:
# Thời gian lên kế hoạch: cuối tháng 10/2025, thời điểm Việt Nam có mưa trên khắp cả nước, với lượng mưa tương đối lớn, đặc biệt có thể kể đến trận lụt vừa mới đây của Huế. __Một chút tò mò và mong muốn cống hiến__,việc nghiên cứu về thời tiết, đặc biệt là mưa trở nên cần thiết.
# - Dựa trên ý tưởng ban đầu là **mưa**, ta sẽ thu thập data dựa trên nó.
# - Qua nghiên cứu: <Tên bài-Tác giả>: <Link nếu có>

# %% [markdown]
# # 2. Quá trình

# %% [markdown]
# - Nguồn data:
#     + Source 1: <Link>
#     Giải thích về nguồn
#     + Source 2: <Link>
#     Giải thích về nguồn
#     + ...
# - Quá trình:
#     + Crawl/Scraping
#     + Call API
#     + Download CSV ultra vip pro
#     + ...
